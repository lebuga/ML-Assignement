# %%
#Imports and reading the data in the Jupyter notebbok
import pandas as pd
import numpy as np

# %%
#Loading my Dataset from Google Drive to Google Colab
#Since the my dataset is stored on drive, need to import the drive and mount it to google drive so as to access the contents

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Visual Assessment of the dataset and acquainting with the different features/columns of dataset
#We display the pandas Dataframe for the gathered dataset,
#The diferent features are explained in the Assignemt Report

# %%
#Display the dataset table
#The dot dot dots.... in the rows indicate that pandas by default doesnt show all the rows
dataset = pd.read_csv("/content/drive/MyDrive/MY-Ml-Projects/dataset.csv")
dataset
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
#Next thing is do basic Understanding of our data
#dataFrame shape,
#.head and .tail
#dTypes
#Describe
#sample
#info
#value_counts
#columns

# %%
#determine the shape of our dataset, how many rows and columns
dataset.shape
# Out:
# (303, 14)

# %%
#Displays all the columns or feature names of the table
dataset.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#Actually diplays the columns with thier data types
dataset.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
#to display the first 5  records from the table
dataset.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#dispaying the last 5 records of the table
dataset.tail(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
#This picks just random samples of records from the dataset table
dataset.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 196   46    1   2       150   231    0        1      147      0      3.6
# 207   60    0   0       150   258    0        0      157      0      2.6
# 253   67    1   0       100   299    0        0      125      1      0.9
# 4     57    0   0       120   354    0        1      163      1      0.6
# 10    54    1   0       140   239    0        1      160      0      1.2
#
#      slope  ca  thal  target
# 196      1   0     2       0
# 207      1   2     3       0
# 253      1   2     2       0
# 4        2   0     2       1
# 10       2   0     2       1

# %%
#Describes the attributes of the different features, data types, memory s=usage, no of columns, total entries and so on
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
dataset.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
dataset.value_counts()
# Out:
# age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  target
# 38   1    2   138       175   0    1        173      0      0.0      2      4   2     1         2
# 59   1    0   110       239   0    0        142      1      1.2      1      1   3     0         1
#           2   126       218   1    1        134      0      2.2      1      1   1     0         1
#           1   140       221   0    1        164      1      0.0      2      0   2     1         1
#           0   170       326   0    0        140      1      3.4      0      0   3     0         1
#                                                                                                ..
# 51   1    2   94        227   0    1        154      1      0.0      2      1   3     1         1
#           0   140       299   0    1        173      1      1.6      2      0   3     0         1
#                         298   0    1        122      1      4.2      1      3   3     0         1
# ...

# %%
#Data Preparation
#here we  can drop irrelevant columns and rows we dont want
#we can identify duplicated columns
#Renaming columns
#creating features

# %%
#Data Cleaning and Data Wrangling
#But we can run .isnull to check id there are missing values in dataset

# %%
#For this dataset, the status is null or full for all the rows and this implies no missing values
#dataset.isnull()
dataset.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#checking a duplicate in the dataset
#Running this and we are able to identify one duplicate on row 164
dataset.loc[dataset.duplicated()]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %%
#There are no null values, no irrelevant features, data types are all okay
#all the columns are named in lower case and there are no spacces in naming, so no need to rename any column
#The proceed to delete the duplicate and clean the data set

# %%
#Delete the duplicate record in the data set and create  anew copy of a clean data set
dataset =dataset.loc[~dataset.duplicated()]\
.reset_index(drop = True).copy()

# %%
#This is the shape of the our new dataset after deleting the duplicates
#It finally has 302 rows and 14 columns
dataset.shape
# Out:
# (302, 14)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
plt.style.use('ggplot')
# %matplotlib inline

# %%
#Also check for Outliers in all the features
#an outlier is a data point that differs significantly from other observations,
#Box Plots
base_color = sb.color_palette()[0]
sb.boxplot(data = dataset,  y ='chol', color = base_color)
plt.xticks(rotation =15);

# %%
def removal_box_plot(dataset, column, threshold):
    #sb.boxplot(dataset[column])
   # plt.title(f'Original Box Plot of {column}')
   # plt.show()

    removed_outliers = dataset[dataset[column] <= threshold]

    sb.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers


threshold_value = 380

no_outliers = removal_box_plot(dataset, 'chol', threshold_value)

# %%
dataset.value_counts()
# Out:
# age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  target
# 29   1    1   130       204   0    0        202      0      0.0      2      0   2     1         1
# 59   1    2   150       212   1    1        157      0      1.6      2      0   2     1         1
#           1   140       221   0    1        164      1      0.0      2      0   2     1         1
#           0   170       326   0    0        140      1      3.4      0      0   3     0         1
#               164       176   1    0        90       0      1.0      1      2   1     0         1
#                                                                                                ..
# 51   1    0   140       299   0    1        173      1      1.6      2      0   3     0         1
#                         298   0    1        122      1      4.2      1      3   3     0         1
#                         261   0    0        186      1      0.0      2      0   2     1         1
# ...

# %%
#After the data is already cleaned, we have a good and clean dat set
#we proceed to understanding some of the features through Univariate or Bivariate Analysis
#This helps to know the distrubtion those features and identify potential outliers
#Histogram
#KDE
#Box PLot

# %%
#Univariate Analysis

dataset['age'].value_counts()
# to test how many unique values occur for that feature
#it will order them from the list to most occuring eg. age 58 occurs most likes or 19 times while 74, 76,77 occur only 1 time
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 56    11
# 44    11
# 60    11
# 41    10
# 64    10
# 67     9
# 63     9
# 43     8
# 55     8
# 42     8
# 61     8
# 65     8
# 53     8
# 45     8
# 50     7
# 48     7
# 46     7
# 66     7
# 47     5
# 49     5
# 70     4
# 39     4
# 68     4
# 35     4
# 71     3
# 40     3
# 69     3
# 34     2
# 37     2
# 38     2
# 29     1
# 74     1
# 76     1
# 77     1
# Name: count, dtype: int64

# %%
#We can also have a plot of persons with most top 10 cholesterol levels
#and see how its distributed
#Before ploting the graph, make sure the some of the pandas libraries are imported into Jupyter

# %%
#Loading the Libraries
#Pre-requisite package imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
plt.style.use('ggplot')
# %matplotlib inline

# %%
#This will now get the top 10 most occuring persons in age and plot a bar graph
dataset['age'].value_counts()\
.head(10)\
.plot(kind ='bar', title ='Top 10 persons with most Age occurence')
plt.xlabel('Age occurence')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
#We could also vizualize cholesterol levels and occurence by making a plot, using histogram
#The histogram shows us in different bins the count of each value
ax =dataset['chol'].plot(kind ='hist',
                         bins =20,
                         title ='Choleterol Occurence')#you can add different bin sizes, this makes it cleaar to visualize
ax.set_xlabel('Cholesterol occurence')
ax.set_ylabel('Frequency of occurence')
#The Cholesterol distribution implies that between 200 and 300, there is high cholesterol occurence
#Also on the extreme far right, there are isolated cases of choleterol occurence
# Out:
# Text(0, 0.5, 'Frequency of occurence')

# %%
#We can as well use a KDE to plot the cholesterol occurence
ax =dataset['chol'].plot(kind ='kde',
                         title ='Choleterol Occurence')
ax.set_xlabel('Cholesterol occurence')
ax.set_ylabel('Frequency of occurence')
#This kde makes the distrubution clear  and very similar to the histogram
# Out:
# Text(0, 0.5, 'Frequency of occurence')

# %%
#Understanding the relationship between the features
#Having undertood the different features and their distributions of a given column in a dataset using plots
#Scatter PLot
#HeatMap Plot Correlation
#PairPlot
#GroupBy Comparisons

#Now we want to find out how did the different features relate to each other in the dataset
#we have to compare the different features in our dataset

# %%
#Now lets plot a relationship between our age and cholesterol levels
dataset.plot(kind ='scatter', x='chol', y = 'age', title = 'Age Vs Cholesterol levels')
#plt.plot([100,500], [50,300])
#the plot implies btn 40 and 70, there are high occurences of cholesteral levels
plt.show()#helps to remove the matlib objects created by pandas

# %%
#We can also use seabom to explore the relationshio betwen two features
#Establish relations betwen resting blood pressure and maximum heart rate
#We can add another feature to be the color (ie the hue = chol)
#We can see we now have different colors based on the choleterol levels ie color the csatter plot based on another variable
sb.scatterplot(x='thalach',
               y ='trestbps',
               hue = 'chol',
               data = dataset)
# Out:
# <Axes: xlabel='thalach', ylabel='trestbps'>

# %%
#How to compare more that two variables in our dataset
sb.pairplot(dataset, vars =['age', 'chol', 'trestbps', 'thalach'], hue ='oldpeak')
plt.show()

# %%
#We can also look at correlation to compare relations between features
#we drop any known null values and then do a correlation
#s seen, some fetures have negative correlatins and others have big correlations
#eg. a positive correlation betwen age and chol implies an increase in age leads to increase in cholesterol(weak correlations)
#nagative correlation btn age and maximum bps implies an increase in age leads to decrease in bp but the correlation is weak one (<-0.3>)
dataset_corr =dataset[['age', 'chol', 'trestbps', 'thalach']].dropna().corr()
dataset_corr
# Out:
#                age      chol  trestbps   thalach
# age       1.000000  0.213678  0.279351 -0.398522
# chol      0.213678  1.000000  0.123174 -0.009940
# trestbps  0.279351  0.123174  1.000000 -0.046698
# thalach  -0.398522 -0.009940 -0.046698  1.000000

# %%
#Another way to perform correlation is by using the Seabon's HeatMap method
#visualize how correlated the values are to each other
#also add annotations to see the raw values
#each value will have a perfect correlation with itself
sb.heatmap(dataset_corr, annot =True)
# Out:
# <Axes: >

# %%
#Asking a question about the data
#This is the final step of the Exploratory Data Analysis Process
#The we try to answer the question about the data using a plot or statistics

# %%
#Qn. Which age bracket has the highest cholesterol levels (minimum of 200 cholesterol and above 5 count)?
#dataset['age'].value_counts()
#As you you can see from the statistics below, the age bracket of 41-67 has the highest average chols levesl of above 200 and most occuring
dataset.groupby('age')['chol']\
       .agg(['mean', 'count'])\
       .query('mean >=200 and count >=5')\
       .sort_values('mean')
# Out:
#            mean  count
# age
# 41   220.700000     10
# 44   221.363636     11
# 50   227.000000      7
# 52   228.230769     13
# 49   228.600000      5
# 46   230.285714      7
# 53   233.500000      8
# 57   238.529412     17
# 59   239.857143     14
# 61   243.750000      8
# 60   245.545455     11
# 66   245.714286      7
# 47   246.400000      5
# 42   246.750000      8
# 45   247.375000      8
# 48   250.857143      7
# 54   253.312500     16
# 58   254.526316     19
# 62   256.636364     11
# 43   256.750000      8
# 63   258.222222      9
# 51   258.666667     12
# 56   259.363636     11
# 64   274.400000     10
# 65   279.000000      8
# 55   280.625000      8
# 67   286.777778      9

# %%
plt.scatter(data = dataset, x = 'thalach', y='chol')
plt.plot([80,200], [100,320])
plt.xlabel('Cholesterol')
plt.ylabel('Max. Heart rate')
# Out:
# Text(0, 0.5, 'Max. Heart rate')
